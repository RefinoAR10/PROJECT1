# %%
import numpy  as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
imdb=pd.read_csv('/content/IMDB_processed_data.csv')
imdb
# Out:
#      Rank                      Title  Release Runtime      Rated  Ratings
# 0       1   The Shawshank Redemption     1994  2h 22m          R      9.3
# 1       2              The Godfather     1972  2h 55m          R      9.2
# 2       3            The Dark Knight     2008  2h 32m      PG-13      9.0
# 3       4      The Godfather Part II     1974  3h 22m          R      9.0
# 4       5               12 Angry Men     1957  1h 36m   Approved      9.0
# ..    ...                        ...      ...     ...        ...      ...
# 245   246              Amores Perros     2000  2h 34m          R      8.0
# 246   247                   The Help     2011  2h 26m      PG-13      8.1
# 247   248                    Rebecca     1940  2h 10m   Approved      8.1
# 248   249  A Silent Voice: The Movie     2016  2h 10m  Not Rated      8.1
# 249   250                  Andhadhun     2018  2h 19m  Not Rated      8.2
#
# [250 rows x 6 columns]

# %%
imdb.head(11)
# Out:
#     Rank                                              Title  Release Runtime  \
# 0      1                           The Shawshank Redemption     1994  2h 22m
# 1      2                                      The Godfather     1972  2h 55m
# 2      3                                    The Dark Knight     2008  2h 32m
# 3      4                              The Godfather Part II     1974  3h 22m
# 4      5                                       12 Angry Men     1957  1h 36m
# 5      6      The Lord of the Rings: The Return of the King     2003  3h 21m
# 6      7                                   Schindler's List     1993  3h 15m
# 7      8                                       Pulp Fiction     1994  2h 34m
# 8      9  The Lord of the Rings: The Fellowship of the Ring     2001  2h 58m
# 9     10                     The Good, the Bad and the Ugly     1966  2h 58m
# 10    11                                       Forrest Gump     1994  2h 22m
#
#        Rated  Ratings
# ...

# %%
imdb.tail(11)
# Out:
#      Rank                      Title  Release Runtime      Rated  Ratings
# 239   240             The Iron Giant     1999  1h 26m         PG      8.1
# 240   241      The Battle of Algiers     1966   2h 1m  Not Rated      8.1
# 241   242              Into the Wild     2007  2h 28m          R      8.1
# 242   243        The Grapes of Wrath     1940   2h 9m   Approved      8.1
# 243   244              Groundhog Day     1993  1h 41m         PG      8.0
# 244   245              A Man Escaped     1956  1h 41m  Not Rated      8.2
# 245   246              Amores Perros     2000  2h 34m          R      8.0
# 246   247                   The Help     2011  2h 26m      PG-13      8.1
# 247   248                    Rebecca     1940  2h 10m   Approved      8.1
# 248   249  A Silent Voice: The Movie     2016  2h 10m  Not Rated      8.1
# 249   250                  Andhadhun     2018  2h 19m  Not Rated      8.2

# %%
imdb.head(20)
# Out:
#     Rank                                              Title  Release Runtime  \
# 0      1                           The Shawshank Redemption     1994  2h 22m
# 1      2                                      The Godfather     1972  2h 55m
# 2      3                                    The Dark Knight     2008  2h 32m
# 3      4                              The Godfather Part II     1974  3h 22m
# 4      5                                       12 Angry Men     1957  1h 36m
# 5      6      The Lord of the Rings: The Return of the King     2003  3h 21m
# 6      7                                   Schindler's List     1993  3h 15m
# 7      8                                       Pulp Fiction     1994  2h 34m
# 8      9  The Lord of the Rings: The Fellowship of the Ring     2001  2h 58m
# 9     10                     The Good, the Bad and the Ugly     1966  2h 58m
# 10    11                                       Forrest Gump     1994  2h 22m
# ...

# %%
imdb.shape
# Out:
# (250, 6)

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     250 non-null    int64
#  1   Title    250 non-null    object
#  2   Release  250 non-null    int64
#  3   Runtime  250 non-null    object
#  4   Rated    250 non-null    object
#  5   Ratings  250 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 11.8+ KB

# %%
imdb.describe()
# Out:
#              Rank     Release     Ratings
# count  250.000000   250.00000  250.000000
# mean   125.500000  1988.17200    8.310000
# std     72.312977    25.59631    0.232716
# min      1.000000  1921.00000    8.000000
# 25%     63.250000  1971.25000    8.100000
# 50%    125.500000  1995.00000    8.200000
# 75%    187.750000  2008.75000    8.400000
# max    250.000000  2024.00000    9.300000

# %%
imdb.select_dtypes(exclude='object')
# Out:
#      Rank  Release  Ratings
# 0       1     1994      9.3
# 1       2     1972      9.2
# 2       3     2008      9.0
# 3       4     1974      9.0
# 4       5     1957      9.0
# ..    ...      ...      ...
# 245   246     2000      8.0
# 246   247     2011      8.1
# 247   248     1940      8.1
# 248   249     2016      8.1
# 249   250     2018      8.2
#
# [250 rows x 3 columns]

# %%
imdb[imdb['Release']==1994].count()
# Out:
# Rank       5
# Title      5
# Release    5
# Runtime    5
# Rated      5
# Ratings    5
# dtype: int64

# %%
imdb.isnull().sum()
# Out:
# Rank       0
# Title      0
# Release    0
# Runtime    0
# Rated      0
# Ratings    0
# dtype: int64

# %%
imdb.isnull().count()
# Out:
# Rank       250
# Title      250
# Release    250
# Runtime    250
# Rated      250
# Ratings    250
# dtype: int64

# %%
imdb.columns
# Out:
# Index(['Rank', 'Title', 'Release', 'Runtime', 'Rated', 'Ratings'], dtype='object')

# %%
sns.countplot(x="Rated", data=imdb)
# Out:
# <Axes: xlabel='Rated', ylabel='count'>

# %%
plt.figure(figsize=(25,30))
sns.countplot(y="Release",data=imdb)
# Out:
# <Axes: xlabel='count', ylabel='Release'>

# %%
plt.figure(figsize=(25,30))
pos=1
for i in imdb.columns:
  plt.subplot(5,2,pos)
  sns.histplot(imdb[i],bins=10,kde=True)
  pos=pos+1

# %%
sns.scatterplot(x="Release",y="Rated",data=imdb)
# Out:
# <Axes: xlabel='Release', ylabel='Rated'>

# %%
col=imdb.columns
col
# Out:
# Index(['Rank', 'Title', 'Release', 'Runtime', 'Rated', 'Ratings'], dtype='object')

# %%
imdb.isnull().sum()
# Out:
# Rank       0
# Title      0
# Release    0
# Runtime    0
# Rated      0
# Ratings    0
# dtype: int64

# %%
year_counts = imdb['Release'].value_counts().sort_index()
fig, ax = plt.subplots(figsize = (12,6))
bars = ax.bar(year_counts.index, year_counts.values)

ax.set_xlabel("Release Year", fontsize = 10)
ax.set_ylabel("Frequency", fontsize = 10)
ax.set_title("No. of Movies Released in a Year", fontsize = 14)
ax.set_xticks(year_counts.index)

ax.tick_params(axis = 'x', labelsize = 8, rotation = 90)
ax.tick_params(axis = 'y', labelsize = 10)

# data labels
for b in bars:
    h = b.get_height()
    ax.text(b.get_x() + b.get_width()/2, h, str(int(h)),
            ha = 'center', va = 'bottom', fontsize = 8)

    fig.tight_layout()
plt.show()

# %%
# average rating for a specific release year

# grouping by 'Release' year and calculating average rating
avg_rating_per_year = imdb.groupby('Release')['Ratings'].mean()

# sorting by year (good for proper x-axis order)
avg_rating_per_year = avg_rating_per_year.sort_index()

plt.figure(figsize = (12,6))
plt.plot(avg_rating_per_year.index, avg_rating_per_year.values, marker = 'o', linestyle = '-')
plt.xticks(avg_rating_per_year.index, rotation = 90, fontsize = 8)
plt.yticks(fontsize = 10)
plt.xlabel("Release Year", fontsize = 10)
plt.ylabel("Average Rating", fontsize = 10)
plt.title("Average Rating for a Specific Release Year", fontsize = 14)

# data labels
for x, y in zip(avg_rating_per_year.index, avg_rating_per_year.values):
    plt.text(x, y+0.01, f"{y:.2f}", ha = 'center', va = 'bottom', fontsize = 8)

plt.tight_layout()
plt.show()

# %%
imdb['Release'].median()
# Out:
# 1995.0

# %%
imdb['Rated'].value_counts()
# Out:
# Rated
# R            101
# PG            39
# PG-13         35
# Not Rated     29
# Approved      22
# G             18
# Passed         5
# NC-17          1
# Name: count, dtype: int64

# %%
imdb['Rated'].mode()
# Out:
# 0    R
# Name: Rated, dtype: object

# %%
imdb['Rated'].unique()
# Out:
# array(['R', 'PG-13', 'Approved', 'PG', 'Not Rated', 'G', 'NC-17',
#        'Passed'], dtype=object)

# %%
imdb.duplicated().sum()
# Out:
# np.int64(0)

# %%
col=imdb.select_dtypes(exclude='object').count()
col
# Out:
# Rank       250
# Release    250
# Ratings    250
# dtype: int64

# %%
for col_name in col.index:
  sns.boxplot(imdb[col_name])
  plt.title(col_name)
  plt.show()

# %%
imdb.duplicated().sum()
# Out:
# np.int64(0)

# %%
col1=imdb.select_dtypes(include='object').count()
col1
# Out:
# Title      250
# Runtime    250
# Rated      250
# dtype: int64

# %%
imdb['Runtime']
# Out:
# 0      2h 22m
# 1      2h 55m
# 2      2h 32m
# 3      3h 22m
# 4      1h 36m
#         ...
# 245    2h 34m
# 246    2h 26m
# 247    2h 10m
# 248    2h 10m
# 249    2h 19m
# Name: Runtime, Length: 250, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in col1.index:
  imdb[i]=le.fit_transform(imdb[i])
imdb
# Out:
#      Rank  Title  Release  Runtime  Rated  Ratings
# 0       1    213     1994       50      7      9.3
# 1       2    186     1972       78      7      9.2
# 2       3    178     2008       60      5      9.0
# 3       4    187     1974       90      7      9.0
# 4       5      0     1957       11      0      9.0
# ..    ...    ...      ...      ...    ...      ...
# 245   246     17     2000       62      7      8.0
# 246   247    196     2011       53      5      8.1
# 247   248    145     1940       37      0      8.1
# 248   249     10     2016       37      3      8.1
# 249   250     19     2018       46      3      8.2
#
# [250 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
for i in imdb.columns:
  imdb[i]=mm.fit_transform(imdb[i].values.reshape(-1, 1))
imdb
# Out:
#          Rank     Title   Release   Runtime     Rated   Ratings
# 0    0.000000  0.855422  0.708738  0.505051  1.000000  1.000000
# 1    0.004016  0.746988  0.495146  0.787879  1.000000  0.923077
# 2    0.008032  0.714859  0.844660  0.606061  0.714286  0.769231
# 3    0.012048  0.751004  0.514563  0.909091  1.000000  0.769231
# 4    0.016064  0.000000  0.349515  0.111111  0.000000  0.769231
# ..        ...       ...       ...       ...       ...       ...
# 245  0.983936  0.068273  0.766990  0.626263  1.000000  0.000000
# 246  0.987952  0.787149  0.873786  0.535354  0.714286  0.076923
# 247  0.991968  0.582329  0.184466  0.373737  0.000000  0.076923
# 248  0.995984  0.040161  0.922330  0.373737  0.428571  0.076923
# 249  1.000000  0.076305  0.941748  0.464646  0.428571  0.153846
#
# [250 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for i in imdb.columns:
  imdb[i]=ss.fit_transform(imdb[i].values.reshape(-1, 1))
imdb
# Out:
#          Rank     Title   Release   Runtime     Rated   Ratings
# 0   -1.725136  1.226302  0.228146  0.183145  0.975944  4.262650
# 1   -1.711280  0.852176 -0.633077  1.262284  0.975944  3.832080
# 2   -1.697423  0.741324  0.776197  0.568552  0.127297  2.970938
# 3   -1.683567  0.866032 -0.554784  1.724773  0.975944  2.970938
# 4   -1.669710 -1.725136 -1.220275 -1.319941 -1.994320  2.970938
# ..        ...       ...       ...       ...       ...       ...
# 245  1.669710 -1.489576  0.463025  0.645634  0.975944 -1.334769
# 246  1.683567  0.990741  0.893636  0.298767  0.127297 -0.904199
# 247  1.697423  0.284059 -1.885765 -0.317884 -1.994320 -0.904199
# 248  1.711280 -1.586571  1.089369 -0.317884 -0.721350 -0.904199
# 249  1.725136 -1.461863  1.167662  0.028983 -0.721350 -0.473628
#
# [250 rows x 6 columns]

# %%
# feature selection
data1=imdb.select_dtypes(exclude='object')
data1
# Out:
#          Rank     Title   Release   Runtime     Rated   Ratings
# 0   -1.725136  1.226302  0.228146  0.183145  0.975944  4.262650
# 1   -1.711280  0.852176 -0.633077  1.262284  0.975944  3.832080
# 2   -1.697423  0.741324  0.776197  0.568552  0.127297  2.970938
# 3   -1.683567  0.866032 -0.554784  1.724773  0.975944  2.970938
# 4   -1.669710 -1.725136 -1.220275 -1.319941 -1.994320  2.970938
# ..        ...       ...       ...       ...       ...       ...
# 245  1.669710 -1.489576  0.463025  0.645634  0.975944 -1.334769
# 246  1.683567  0.990741  0.893636  0.298767  0.127297 -0.904199
# 247  1.697423  0.284059 -1.885765 -0.317884 -1.994320 -0.904199
# 248  1.711280 -1.586571  1.089369 -0.317884 -0.721350 -0.904199
# 249  1.725136 -1.461863  1.167662  0.028983 -0.721350 -0.473628
#
# [250 rows x 6 columns]

# %%
res1=imdb.corr()
res1
# Out:
#              Rank     Title   Release   Runtime     Rated   Ratings
# Rank     1.000000  0.031413 -0.033139 -0.168750 -0.166476 -0.844493
# Title    0.031413  1.000000 -0.100970 -0.024122 -0.069815  0.007338
# Release -0.033139 -0.100970  1.000000  0.020104  0.446558  0.046568
# Runtime -0.168750 -0.024122  0.020104  1.000000  0.140420  0.209077
# Rated   -0.166476 -0.069815  0.446558  0.140420  1.000000  0.093908
# Ratings -0.844493  0.007338  0.046568  0.209077  0.093908  1.000000

# %%
# multicollinarity
res=imdb[imdb.columns[::-1]].corr()
res
# Out:
#           Ratings     Rated   Runtime   Release     Title      Rank
# Ratings  1.000000  0.093908  0.209077  0.046568  0.007338 -0.844493
# Rated    0.093908  1.000000  0.140420  0.446558 -0.069815 -0.166476
# Runtime  0.209077  0.140420  1.000000  0.020104 -0.024122 -0.168750
# Release  0.046568  0.446558  0.020104  1.000000 -0.100970 -0.033139
# Title    0.007338 -0.069815 -0.024122 -0.100970  1.000000  0.031413
# Rank    -0.844493 -0.166476 -0.168750 -0.033139  0.031413  1.000000

# %%
# to get greater than 80%
res[res>0.8]
# Out:
#          Ratings  Rated  Runtime  Release  Title  Rank
# Ratings      1.0    NaN      NaN      NaN    NaN   NaN
# Rated        NaN    1.0      NaN      NaN    NaN   NaN
# Runtime      NaN    NaN      1.0      NaN    NaN   NaN
# Release      NaN    NaN      NaN      1.0    NaN   NaN
# Title        NaN    NaN      NaN      NaN    1.0   NaN
# Rank         NaN    NaN      NaN      NaN    NaN   1.0

# %%
res=imdb[imdb.columns[::-1]].corr()
res
# Out:
#           Ratings     Rated   Runtime   Release     Title      Rank
# Ratings  1.000000  0.093908  0.209077  0.046568  0.007338 -0.844493
# Rated    0.093908  1.000000  0.140420  0.446558 -0.069815 -0.166476
# Runtime  0.209077  0.140420  1.000000  0.020104 -0.024122 -0.168750
# Release  0.046568  0.446558  0.020104  1.000000 -0.100970 -0.033139
# Title    0.007338 -0.069815 -0.024122 -0.100970  1.000000  0.031413
# Rank    -0.844493 -0.166476 -0.168750 -0.033139  0.031413  1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x=imdb[imdb.columns[::-1]]
y=imdb['Ratings']

vif_df=pd.DataFrame({
    'features':x.columns,
    'vif':[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
})
print(vif_df.sort_values('vif',ascending=False))
# Out:
#   features       vif
# 5     Rank  3.638151
# 0  Ratings  3.627724
# 1    Rated  1.329415
# 3  Release  1.273596
# 2  Runtime  1.067164
# 4    Title  1.016540

# %%
# model creation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.75,random_state=42)
x_train
# Out:
#       Ratings     Rated   Runtime   Release     Title      Rank
# 89  -0.043057 -0.721350  0.183145 -0.124173 -1.129306 -0.491906
# 8    2.540367  0.127297  1.300825  0.502171  1.101593 -1.614284
# 13   2.109797  0.127297  0.375849  0.854490 -0.547332 -1.545002
# 59   0.387514  0.975944 -0.048099  0.697904  1.087737 -0.907602
# 215 -0.904199  0.975944 -0.510587  0.384732  0.713611  1.254015
# ..        ...       ...       ...       ...       ...       ...
# 106 -0.043057  0.551621 -1.204319 -2.238084 -0.242489 -0.256346
# 14   1.679226 -0.297026  1.108122 -0.319905  0.602759 -1.531145
# 92  -0.043057 -0.297026 -0.279343 -0.202466  0.616615 -0.450337
# 179 -0.904199  0.127297 -0.240802  0.619611 -0.145493  0.755180
# 102 -0.043057 -1.994320 -0.895994 -1.729179 -1.018454 -0.311772
#
# [62 rows x 6 columns]

# %%
# to create or building the model
l_model=LinearRegression()
l_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=l_model.predict(x_test)
y_pred
# Out:
# array([-0.47362783,  2.97093821, -0.04305708,  0.38751368, -0.47362783,
#        -0.90419859, -0.90419859, -0.90419859,  2.1097967 , -0.04305708,
#        -0.47362783, -0.90419859, -0.47362783, -0.90419859,  0.38751368,
#         1.67922595, -0.90419859,  1.67922595, -0.90419859,  1.24865519,
#        -0.90419859,  1.24865519, -0.04305708,  0.38751368, -0.90419859,
#         0.81808444,  0.38751368,  2.1097967 ,  1.24865519, -0.47362783,
#        -0.90419859,  0.81808444, -0.47362783, -0.90419859,  1.24865519,
#        -0.04305708,  1.67922595, -0.90419859, -0.90419859, -0.47362783,
#        -0.47362783, -0.04305708, -0.47362783, -0.90419859, -0.90419859,
#         1.67922595, -0.47362783,  0.38751368, -0.90419859,  0.81808444,
#        -0.47362783, -0.90419859, -0.90419859, -0.04305708, -0.47362783,
#         0.38751368, -0.90419859, -0.47362783, -0.90419859, -0.90419859,
#        -0.90419859, -0.47362783, -0.04305708,  0.38751368, -0.04305708,
# ...

# %%
from sklearn.metrics import r2_score
r2_on_test=r2_score(y_test,y_pred)
r2_on_test
# Out:
# 1.0

# %%
weights=l_model.coef_
intercept=l_model.intercept_
print(weights)
print(intercept)
x_test
# Out:
# [ 1.00000000e+00  3.94764465e-16 -1.34205030e-16  5.56810359e-16
#  -1.50193819e-16  7.23096011e-16]
# 9.367506770274758e-17
#       Ratings     Rated   Runtime   Release     Title      Rank
# 142 -0.473628  0.127297 -0.895994  0.423878  1.267871  0.242489
# 6    2.970938  0.975944  1.609151  0.188999  0.394911 -1.641997
# 97  -0.043057  0.975944 -1.204319  0.149853  0.311772 -0.381054
# 60   0.387514  0.127297  0.414389  1.167662 -1.420293 -0.893745
# 112 -0.473628  0.975944 -0.086639 -0.672224 -1.628141 -0.173206
# ..        ...       ...       ...       ...       ...       ...
# 110 -0.043057  0.975944  0.452930  0.502171 -1.475719 -0.200920
# 91  -0.043057 -1.569997 -1.050157  0.854490  1.545002 -0.464193
# 83   0.387514 -0.721350  0.221686 -0.985396 -0.644328 -0.575045
# 223 -0.904199 -0.721350 -1.242860  0.267292 -0.339485  1.364867
# 228 -0.904199  0.975944  0.452930 -0.593931  0.810606  1.434150
#
# [188 rows x 6 columns]

# %%
l_model.coef_
# Out:
# array([ 1.00000000e+00,  3.94764465e-16, -1.34205030e-16,  5.56810359e-16,
#        -1.50193819e-16,  7.23096011e-16])

# %%
l_model.intercept_
# Out:
# np.float64(9.367506770274758e-17)

# %%
# Calculate predicted values using weights and intercept
y_pred_manual = x_test.dot(weights) + intercept
print(y_pred_manual)
# Out:
# 142   -0.473628
# 6      2.970938
# 97    -0.043057
# 60     0.387514
# 112   -0.473628
#          ...
# 110   -0.043057
# 91    -0.043057
# 83     0.387514
# 223   -0.904199
# 228   -0.904199
# Length: 188, dtype: float64

# %%
pd.DataFrame({'pred':y_pred,'actual':y_test,'error':y_pred-y_test})
# Out:
#          pred    actual         error
# 142 -0.473628 -0.473628  1.665335e-16
# 6    2.970938  2.970938  8.881784e-16
# 97  -0.043057 -0.043057  3.747003e-16
# 60   0.387514  0.387514  6.106227e-16
# 112 -0.473628 -0.473628 -1.110223e-16
# ..        ...       ...           ...
# 110 -0.043057 -0.043057  7.494005e-16
# 91  -0.043057 -0.043057 -5.134781e-16
# 83   0.387514  0.387514 -8.326673e-16
# 223 -0.904199 -0.904199  6.661338e-16
# 228 -0.904199 -0.904199  3.330669e-16
#
# [188 rows x 3 columns]

# %%
import math
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=math.sqrt(mean_squared_error(y_test,y_pred))
print(mse,mae,rmse)
# Out:
# 7.120142515783181e-31 6.922653939451276e-16 8.438093692169566e-16

# %%
sns.regplot(x=y_pred,y=y_test)
plt.xlabel('Predictions')
plt.ylabel('Actual Values')
plt.title('Regression Plot of Predictions vs Actual Values')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
r_model=RandomForestRegressor()
r_model.fit(x_train,y_train)
y_pred=r_model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_on_test=r2_score(y_test,y_pred)
r2_on_test
# Out:
# 0.9803950168322181
